# %% [markdown]
# <a href="https://colab.research.google.com/github/Gulzona/CodingBat1/blob/master/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=['a', 'c', 'd', 'e'])

# %%
s1
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
s2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1], index=['a', 'c', 'e', 'f', 'g'])

# %%
s2
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %%
s1+s2
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %%
s1.index
# Out:
# Index(['a', 'c', 'd', 'e'], dtype='object')

# %%
s2.index
# Out:
# Index(['a', 'c', 'e', 'f', 'g'], dtype='object')

# %%
s1.values
# Out:
# array([ 7.3, -2.5,  3.4,  1.5])

# %%
s2.values
# Out:
# array([-2.1,  3.6, -1.5,  4. ,  3.1])

# %%
df1 = pd.DataFrame(np.arange(9.).reshape(3,3), columns=list('bcd'), index=['Olma','Anor','Uzum'])

# %%
df1
# Out:
#         b    c    d
# Olma  0.0  1.0  2.0
# Anor  3.0  4.0  5.0
# Uzum  6.0  7.0  8.0

# %%
df2 = pd.DataFrame(np.arange(12.).reshape(4,3), columns=list('abc'), index=['Olma','Anor','Qovun','Anjir'])

# %%
df2
# Out:
#          a     b     c
# Olma   0.0   1.0   2.0
# Anor   3.0   4.0   5.0
# Qovun  6.0   7.0   8.0
# Anjir  9.0  10.0  11.0

# %%
df1+df2
# Out:
#         a    b    c   d
# Anjir NaN  NaN  NaN NaN
# Anor  NaN  7.0  9.0 NaN
# Olma  NaN  1.0  3.0 NaN
# Qovun NaN  NaN  NaN NaN
# Uzum  NaN  NaN  NaN NaN

# %%
df1.add(df2)
# Out:
#         a    b    c   d
# Anjir NaN  NaN  NaN NaN
# Anor  NaN  7.0  9.0 NaN
# Olma  NaN  1.0  3.0 NaN
# Qovun NaN  NaN  NaN NaN
# Uzum  NaN  NaN  NaN NaN

# %%
df1-df2
# Out:
#         a    b    c   d
# Anjir NaN  NaN  NaN NaN
# Anor  NaN -1.0 -1.0 NaN
# Olma  NaN -1.0 -1.0 NaN
# Qovun NaN  NaN  NaN NaN
# Uzum  NaN  NaN  NaN NaN

# %% [markdown]
# add, radd - Qo'shish (+)
# sub, rsub - Ayirish (-)
# div, rdiv - Bo'lish (/)
# floordiv, rfloordiv - Bo'lish va butun qismini olis (//)
# mul, rmul - Ko'paytirish (*)
# pow, rpow - Eksponenta (**)

# %%
df3 = pd.DataFrame(np.random.randn(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df3
# Out:
#        Olma      Anor     Qovun     Anjir
# a -0.571671  0.803789  0.965537  1.080735
# b -0.439385  1.209480 -0.721086  0.898469
# c -0.396348  1.355801 -0.231326 -0.342200

# %%
np.abs(df3)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  0.571671  0.803789  0.965537  1.080735
# b  0.439385  1.209480  0.721086  0.898469
# c  0.396348  1.355801  0.231326  0.342200

# %%
np.round(df3)
# Out:
#    Olma  Anor  Qovun  Anjir
# a  -1.0   1.0    1.0    1.0
# b  -0.0   1.0   -1.0    1.0
# c  -0.0   1.0   -0.0   -0.0

# %%
df3.mean()
# Out:
# Olma    -0.469135
# Anor     1.123023
# Qovun    0.004375
# Anjir    0.545668
# dtype: float64

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/usa_cars.csv', index_col=0)
df.head()
# Out:
#    price      brand    model  year   title_status  mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1   2899       ford       se  2011  clean vehicle   190552  silver
# 2   5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3  25000       ford     door  2014  clean vehicle    64146    blue
# 4  27700  chevrolet     1500  2018  clean vehicle     6654     red
#
#                    vin        lot       state country      condition
# 0    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
df.head(2000)
# Out:
#       price      brand    model  year   title_status  mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1      2899       ford       se  2011  clean vehicle   190552  silver
# 2      5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3     25000       ford     door  2014  clean vehicle    64146    blue
# 4     27700  chevrolet     1500  2018  clean vehicle     6654     red
# ...     ...        ...      ...   ...            ...      ...     ...
# 1995  31831       ford    doors  2018  clean vehicle    14059   black
# 1996  40400       ford      srw  2019  clean vehicle    13472   black
# 1997  15400       ford     door  2013  clean vehicle   123983  silver
# 1998  13500       ford   hybrid  2019  clean vehicle    35023    gray
# 1999  25995       ford    doors  2015  clean vehicle    39509   white
#
#                       vin        lot          state country      condition
# ...

# %%
df.shape
# Out:
# (2499, 12)

# %%
df.size
# Out:
# 29988

# %%
df.sort_index()
# Out:
#       price      brand    model  year   title_status  mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1      2899       ford       se  2011  clean vehicle   190552  silver
# 2      5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3     25000       ford     door  2014  clean vehicle    64146    blue
# 4     27700  chevrolet     1500  2018  clean vehicle     6654     red
# ...     ...        ...      ...   ...            ...      ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle    23609     red
# 2495   9200     nissan    versa  2018  clean vehicle    34553  silver
# 2496   9200     nissan    versa  2018  clean vehicle    31594  silver
# 2497   9200     nissan    versa  2018  clean vehicle    32557   black
# 2498   9200     nissan    versa  2018  clean vehicle    31371  silver
#
#                       vin        lot       state country      condition
# ...

# %%
df.loc[0]
# Out:
# price                          6300
# brand                        toyota
# model                       cruiser
# year                           2008
# title_status          clean vehicle
# mileage                      274117
# color                         black
# vin               jtezu11f88k007763
# lot                       159348797
# state                    new jersey
# country                         usa
# condition              10 days left
# Name: 0, dtype: object

# %%
df['rank'] = df['mileage'].rank()
df
# Out:
#       price      brand    model  year   title_status  mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1      2899       ford       se  2011  clean vehicle   190552  silver
# 2      5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3     25000       ford     door  2014  clean vehicle    64146    blue
# 4     27700  chevrolet     1500  2018  clean vehicle     6654     red
# ...     ...        ...      ...   ...            ...      ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle    23609     red
# 2495   9200     nissan    versa  2018  clean vehicle    34553  silver
# 2496   9200     nissan    versa  2018  clean vehicle    31594  silver
# 2497   9200     nissan    versa  2018  clean vehicle    32557   black
# 2498   9200     nissan    versa  2018  clean vehicle    31371  silver
#
#                       vin        lot       state country      condition  \
# ...

# %%
df['rank'] = df['year'].rank()
df.sort_values('year')
# Out:
#       price      brand     model  year       title_status  mileage  \
# 32    29800  chevrolet    camaro  1973      clean vehicle    46226
# 405      25       ford      door  1984  salvage insurance    41577
# 545       0        gmc      door  1993  salvage insurance        0
# 362      25       ford    pickup  1994  salvage insurance   206162
# 322       0       ford   chassis  1994  salvage insurance        0
# ...     ...        ...       ...   ...                ...      ...
# 426   55600      lexus        gx  2020      clean vehicle     8186
# 806   28300  chevrolet  colorado  2020      clean vehicle    13886
# 2322  15000     nissan    altima  2020      clean vehicle    14320
# 2344  20100     nissan     rogue  2020      clean vehicle    10875
# 1388  17000       ford    fusion  2020      clean vehicle     1117
#
#            color                  vin        lot         state country  \
# 32           red        1q87t3n166389  167763370  pennsylvania     usa
# ...

# %%
d = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv', index_col=0)
d.columns = ['maydoni','aholisi']
d
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
d.sum()
# Out:
# maydoni      441900.0
# aholisi    22945800.0
# dtype: float64

# %%
d.idxmin()
# Out:
# maydoni     Andijon viloyati
# aholisi    Sirdaryo viloyati
# dtype: object

# %%
d['maydoni'].argmax()
# Out:
# 8

# %%
d['maydoni'].argmin()
# Out:
# 0

# %%
d['aholisi'].argmin()
# Out:
# 10

# %%
d['aholisi'].argmax()
# Out:
# 12

# %%
d2 = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/gm_sales.csv", index_col=0)
d2.head()
# Out:
#          2020   2021
# Labo     4521   7542
# Damas   30889  33682
# Spark   16370   6485
# Nexia   41663  14442
# Cobalt  44901  36317

# %%
d2.sum()
# Out:
# 2020    168712
# 2021    124734
# dtype: int64

# %%
d2.sum(axis=1) # yoki axis='columns'
# Out:
# Labo      12063
# Damas     64571
# Spark     22855
# Nexia     56105
# Cobalt    81218
# Gentra    56634
# dtype: int64

# %%
d.describe()
# Out:
#              maydoni       aholisi
# count      13.000000  1.300000e+01
# mean    33992.307692  1.765062e+06
# std     47224.895651  1.003012e+06
# min      4200.000000  6.481000e+05
# 25%      6800.000000  1.200000e+06
# 50%     16400.000000  1.676000e+06
# 75%     28400.000000  2.029000e+06
# max    160000.000000  4.450000e+06
